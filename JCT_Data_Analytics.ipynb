# %% [markdown]
# <a href="https://colab.research.google.com/github/joelthekevin/JCT-Data-Analytics/blob/main/JCT_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Challenge1: Practise Python Basics using String and Number Functions**

# %% [markdown]
# **Task 1: Reverse a string**

# %%
def reverse_string(text):
    return text[::-1]

input_string = input("Enter a string: ")
reversed_string = reverse_string(input_string)

print("Reversed string:", reversed_string)
# Out:
# Enter a string: hello
# Reversed string: olleh

# %% [markdown]
# **Task2: Count vowels in a string**

# %%
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0

    for char in text:
        if char in vowels:
            count += 1

    return count

input_string = input("Enter a string: ")
vowel_count = count_vowels(input_string)
print("Number of vowels:", vowel_count)
# Out:
# Enter a string: Joker
# Number of vowels: 2

# %% [markdown]
# # **Task3: Check Palindrome Number**

# %%
def is_palindrome_number(num):
    num_str = str(num)

    if num_str == num_str[::-1]:
        return "true"
    else:
        return "false"

number = int(input("Enter a number: "))
result = is_palindrome_number(number)
print(result)
# Out:
# Enter a number: 321
# false

# %%
def is_palindrome_number(num):
    num_str = str(num)

    if num_str == num_str[::-1]:
        return "true"
    else:
        return "false"

number = int(input("Enter a number: "))
result = is_palindrome_number(number)
print(result)
# Out:
# Enter a number: 121
# true
