# %%
Challenge 7: Python Exception Handling Mastery

# %%
Task 1: Raising Custom Exceptions

# %%
class InvalidAmountError(Exception):
    def __init__(self, message="Invalid transaction amount! Amount must be greater than zero."):
        self.message = message
        super().__init__(self.message)

try:
    amount = float(input("Enter transaction amount: "))
    if amount <= 0:
        raise InvalidAmountError()
    print(f"Transaction successful! Amount entered: {amount}")
except InvalidAmountError as e:
    print(f"Error: {e}")
except ValueError:
    print("Error: Please enter a valid numeric amount.")
# Out:
# Enter transaction amount:  19
# Transaction successful! Amount entered: 19.0

# %%
Task 2: Cleanup Task with Finally clause

# %%
def file_operation():
    file = None
    try:
        file = open("sample.txt", "r")
        print("File opened successfully.")

        content = file.read()
        print("File content:")
        print(content)
    except FileNotFoundError:
        print("Error: File not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    finally:
        if file:
            file.close()
            print("File has been closed (cleanup done).")

file_operation()
# Out:
# Error: File not found.
